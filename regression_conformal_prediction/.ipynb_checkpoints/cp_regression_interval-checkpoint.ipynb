# %%
import polars as pl
import numpy as np
import pandas as pd
import altair as alt


from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error
from mapie.regression import MapieRegressor

# %%
rent = pl.read_csv("http://www.bamlss.org/misc/rent99.raw", separator=" ")

# %%
y = rent["rentsqm"]
X = rent.drop("rent", "rentsqm", "cheating")

# %%
X_train, X_rest1, y_train, y_rest1 = train_test_split(X, y, test_size=2000, random_state=2)

X_test, X_rest2, y_test, y_rest2 = train_test_split(X_rest1, y_rest1, test_size=1500, random_state=4)

X_calib, X_new, y_calib, y_new = train_test_split(X_rest2, y_rest2, test_size=500, random_state=42)

# %%
(len(X_train), len(X_test), len(X_calib), len(X_new))
# Out:
# (1082, 500, 1000, 500)

# %%
params = {
    "n_estimators": [10, 50, 100, 500, 1000],
    "max_depth": [None, 1, 2, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

# %%
random_search = (
    RandomizedSearchCV(
        estimator=RandomForestRegressor(),
        param_distributions=params,
        cv=5,
        n_iter=10,
        random_state=1,
        verbose=5
    )
)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.312 total time=   1.6s
# [CV 2/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.368 total time=   1.7s
# [CV 3/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.345 total time=   1.6s
# [CV 4/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.197 total time=   1.5s
# [CV 5/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=1000;, score=0.300 total time=   1.6s
# [CV 1/5] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.362 total time=   0.1s
# [CV 2/5] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.379 total time=   0.1s
# [CV 3/5] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.367 total time=   0.1s
# [CV 4/5] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.220 total time=   0.1s
# [CV 5/5] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.317 total time=   0.1s
# [CV 1/5] END max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.310 total time=   0.5s
# [CV 2/5] END max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.323 total time=   0.5s
# [CV 3/5] END max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.305 total time=   0.5s
# [CV 4/5] END max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.208 total time=   0.5s
# [CV 5/5] END max_depth=2, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.280 total time=   0.4s
# [CV 1/5] END max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.205 total time=   0.1s
# [CV 2/5] END max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.201 total time=   0.1s
# [CV 3/5] END max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.180 total time=   0.1s
# [CV 4/5] END max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.152 total time=   0.1s
# [CV 5/5] END max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.174 total time=   0.1s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.316 total time=   0.0s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.345 total time=   0.0s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.316 total time=   0.0s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.152 total time=   0.0s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=0.283 total time=   0.0s
# [CV 1/5] END max_depth=2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.309 total time=   0.9s
# [CV 2/5] END max_depth=2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.322 total time=   0.9s
# [CV 3/5] END max_depth=2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.307 total time=   0.9s
# [CV 4/5] END max_depth=2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.206 total time=   0.9s
# [CV 5/5] END max_depth=2, min_samples_leaf=2, min_samples_split=10, n_estimators=1000;, score=0.278 total time=   0.9s
# [CV 1/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=0.317 total time=   0.8s
# [CV 2/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=0.363 total time=   0.8s
# [CV 3/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=0.346 total time=   0.8s
# [CV 4/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=0.202 total time=   0.8s
# [CV 5/5] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500;, score=0.302 total time=   0.8s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.318 total time=   1.7s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.355 total time=   1.7s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.353 total time=   1.7s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.190 total time=   1.7s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=1000;, score=0.235 total time=   1.7s
# [CV 1/5] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.350 total time=   0.0s
# [CV 2/5] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.384 total time=   0.0s
# [CV 3/5] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.355 total time=   0.0s
# [CV 4/5] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.193 total time=   0.0s
# [CV 5/5] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=0.300 total time=   0.0s
# [CV 1/5] END max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=1000;, score=0.207 total time=   0.8s
# [CV 2/5] END max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=1000;, score=0.205 total time=   0.8s
# [CV 3/5] END max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=1000;, score=0.177 total time=   0.8s
# [CV 4/5] END max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=1000;, score=0.148 total time=   0.8s
# [CV 5/5] END max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=1000;, score=0.184 total time=   0.8s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [None, 1, 2, 5, 10],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [10, 50, 100, 500,
#                                                          1000]},
#                    random_state=1, verbose=5)

# %%
y_pred = random_search.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
mapie_reg = MapieRegressor(estimator=random_search, cv="prefit")

# %%
mapie_reg.fit(X_calib, y_calib)
# Out:
# MapieRegressor(cv='prefit',
#                estimator=RandomizedSearchCV(cv=5,
#                                             estimator=RandomForestRegressor(),
#                                             param_distributions={'max_depth': [None,
#                                                                                1,
#                                                                                2,
#                                                                                5,
#                                                                                10],
#                                                                  'min_samples_leaf': [1,
#                                                                                       2,
#                                                                                       4],
#                                                                  'min_samples_split': [2,
#                                                                                        5,
#                                                                                        10],
#                                                                  'n_estimators': [10,
#                                                                                   50,
#                                                                                   100,
#                                                                                   500,
#                                                                                   1000]},
#                                             random_state=1, verbose=5),
#                method='base')

# %%
y_pred, y_pis = mapie_reg.predict(X_new, alpha=0.33)
# As alpha we choose 0.33 so that on average 2/3 of the true rents are covered by the intervals

# %%
(X_new[0], y_pred[0], y_pis[0])
# Out:
# (shape: (1, 6)
#  ┌──────┬────────┬──────────┬──────┬─────────┬──────────┐
#  │ area ┆ yearc  ┆ location ┆ bath ┆ kitchen ┆ district │
#  │ ---  ┆ ---    ┆ ---      ┆ ---  ┆ ---     ┆ ---      │
#  │ i64  ┆ f64    ┆ i64      ┆ i64  ┆ i64     ┆ i64      │
#  ╞══════╪════════╪══════════╪══════╪═════════╪══════════╡
#  │ 47   ┆ 1932.0 ┆ 1        ┆ 0    ┆ 0       ┆ 1812     │
#  └──────┴────────┴──────────┴──────┴─────────┴──────────┘,
#  7.24001502990723,
#  np.float64(6.018078891130704),
#  array([[4.08406608],
#         [7.9520917 ]]))

# %%
area = X_new[0]["area"]

# %%
(
    X_new[0],
    y_new[0]
)
# Out:
# (shape: (1, 6)
#  ┌──────┬────────┬──────────┬──────┬─────────┬──────────┐
#  │ area ┆ yearc  ┆ location ┆ bath ┆ kitchen ┆ district │
#  │ ---  ┆ ---    ┆ ---      ┆ ---  ┆ ---     ┆ ---      │
#  │ i64  ┆ f64    ┆ i64      ┆ i64  ┆ i64     ┆ i64      │
#  ╞══════╪════════╪══════════╪══════╪═════════╪══════════╡
#  │ 47   ┆ 1932.0 ┆ 1        ┆ 0    ┆ 0       ┆ 1812     │
#  └──────┴────────┴──────────┴──────┴─────────┴──────────┘,
#  5.8036003112793)

# %%
(
    area*y_pred[0],
    area*y_pis[0],
    area*y_new[0]
)
# Out:
# (shape: (1,)
#  Series: 'area' [f64]
#  [
#  	282.849708
#  ],
#  shape: (2,)
#  Series: 'area' [array[f64, 1]]
#  [
#  	[191.951106]
#  	[373.74831]
#  ],
#  shape: (1,)
#  Series: 'area' [f64]
#  [
#  	272.769215
#  ])

# %%
df = (
    pl.DataFrame()
    .with_columns(
        y_truth=y_new,
        y_pred=y_pred,
        y_unnested = y_pis,
        area = X_new["area"]
    )
    .explode(columns="y_unnested")
    .explode(columns="y_unnested") # to get rid of all parentheses
    .with_columns(
        y_unnested = pl.col("y_unnested").cast(pl.Float32)
    )
)

# %%
layer1 = (
    df.plot.point(
        y="y_truth",
        x= "area"
    )
    .properties(width=1000)
)

# %%
layer2 = (
    df.plot.point(
        y="y_pred",
        x="area",
        color="y_pred"
    )# Optional: specify color for differentiation
)

# %%
layer1 + layer2
# Out:
# alt.LayerChart(...)

# %%
df.with_columns(
        y_unnested = y_unnested.cast(pl.Float32)
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 2
#       1 df.with_columns(
# ----> 2         y_unnested = y_unnested.cast(pl.Float32)
#       3     )
#
# NameError: name 'y_unnested' is not defined
